# %% [markdown]
# # 三种方法插入图片

# %% [markdown]
# ![石原里美](./shiyuan.jpg)

# %% [markdown]
# ![石原](https://b-ssl.duitang.com/uploads/item/201803/17/20180317220355_fGnkY.thumb.700_0.jpeg)

# %% [markdown]
# <img src='./shiyuan.jpg', width=200>

# %%
from IPython.display import Image
Image(filename='./shiyuan.jpg', width=300)
